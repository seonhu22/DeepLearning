# %%
# sklearn 라이브러리에서 기본 제공하는 Breast Cancer Wisconsin Dataset을
# 불러온 후 Pandas로 표기
from sklearn.datasets import load_breast_cancer
import pandas as pd

dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns = dataset.feature_names)

df
# Out:
#      mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 0          17.99         10.38  ...          0.4601                  0.11890
# 1          20.57         17.77  ...          0.2750                  0.08902
# 2          19.69         21.25  ...          0.3613                  0.08758
# 3          11.42         20.38  ...          0.6638                  0.17300
# 4          20.29         14.34  ...          0.2364                  0.07678
# ..           ...           ...  ...             ...                      ...
# 564        21.56         22.39  ...          0.2060                  0.07115
# 565        20.13         28.25  ...          0.2572                  0.06637
# 566        16.60         28.08  ...          0.2218                  0.07820
# 567        20.60         29.33  ...          0.4087                  0.12400
# 568         7.76         24.54  ...          0.2871                  0.07039
#
# [569 rows x 30 columns]

# %%
# 데이터의 결측치를 확인 후 처리
from sklearn.datasets import load_breast_cancer
import pandas as pd

dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns = dataset.feature_names)

print(df_fillna.any().any())

df_fillna = df.fillna(method = 'ffill')

print(df_fillna.isnull().any().any())
# Out:
# True
# False

# %%
# 데이터셋을 col별 평균을 구해 시각화
from sklearn.datasets import load_breast_cancer
import pandas as pd
import matplotlib.pyplot as plt

dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns = dataset.feature_names)
df_mean = pd.DataFrame(df.mean())

df_mean.plot()

# %%
# train dataset과 test dataset으로 분류
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

dataset = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size = 0.2, shuffle = True)

pd.DataFrame(x_train)
# Out:
#          0      1       2       3   ...       26       27      28       29
# 0    21.160  23.04  137.20  1404.0  ...  0.31550  0.20090  0.2822  0.07526
# 1    10.480  14.98   67.49   333.6  ...  0.29390  0.09310  0.3020  0.09646
# 2     8.726  15.83   55.84   230.9  ...  0.24560  0.10500  0.2926  0.10170
# 3    11.080  18.83   73.30   361.6  ...  0.84020  0.25240  0.4154  0.14030
# 4    11.540  10.72   73.73   409.1  ...  0.08324  0.04715  0.3390  0.07434
# ..      ...    ...     ...     ...  ...      ...      ...     ...      ...
# 450  14.340  13.47   92.51   641.2  ...  0.16320  0.10870  0.3062  0.06072
# 451  10.750  14.97   68.26   355.3  ...  0.09755  0.03413  0.2300  0.06769
# 452  12.560  19.07   81.92   485.8  ...  0.23880  0.09265  0.2121  0.07188
# 453  13.170  21.81   85.42   531.5  ...  0.37280  0.16070  0.3693  0.09618
# 454  13.880  16.16   88.37   596.6  ...  0.10910  0.04537  0.2542  0.06623
#
# [455 rows x 30 columns]

# %%
# Decision Tree Classifier을 이용해 정확도 계산
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dataset = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size = 0.2, shuffle = True)
clf = DecisionTreeClassifier()

clf.fit(x_train, y_train)

pred = clf.predict(x_test)
accuracy_score(y_test, pred)
# Out:
# 0.9122807017543859

# %%
# Breast Cancer 데이터 셋을 Random Forest 모델을 이용하여 분류
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

dataset = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size = 0.2, shuffle = True)
clf = RandomForestClassifier()

clf.fit(x_train, y_train)

pred = clf.predict(x_test)
accuracy_score(y_test, pred)
# Out:
# 0.9649122807017544

# %%
# RandomForest로 분류한 뒤 Feature Importance를 출력
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

dataset = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size = 0.2, shuffle = True)
clf = RandomForestClassifier()

clf.fit(x_train, y_train)

fig, ax = plt.subplots(figsize=(12, 20))
feature_importances = clf.feature_importances_

y_pos = np.arange(len(feature_importances))

ax.barh(y_pos, feature_importances, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(dataset.feature_names)
ax.invert_yaxis()
ax.set_xlabel('Performance')
ax.set_title('Feature Importance of Random Forest Classifier')

plt.show()

# %%
# 지금까지 어떤 데이터를 사용했고, 어떤 모델로, 어떤 작업을 수행하였으며 그 결과를 어떻게 평가했는지에 대해 정리
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


dataset = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size = 0.2, shuffle = True)
clf = RandomForestClassifier()


clf.fit(x_train, y_train)


pred = clf.predict(x_test)
accuracy_score(y_test, pred)
# sklearn 라이브러리에서 제공하는 breast cancer라는 데이터셋을 사용해서

# train dataset, test dataset을 8:2 비율로 나누고

# sklearn 라이브러리에서 제공하는 RandomForestClassifier를 사용해서 fit함

# 학습한 데이터로 pred해서 acc로 얼마나 정확도가 좋은지 평가
# Out:
# 0.956140350877193
